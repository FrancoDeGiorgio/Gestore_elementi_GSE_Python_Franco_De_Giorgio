# %% [markdown]
# # 🌿 LookBook
# > *Un nuovo modo di dare vita ai vestiti dimenticati*
#
# ![LookBook Logo](https://videos.openai.com/vg-assets/assets%2Ftask_01jtp6htpqec9va99eqkv2qpyx%2F1746649335_img_0.webp?st=2025-05-07T18%3A42%3A58Z&se=2025-05-13T19%3A42%3A58Z&sks=b&skt=2025-05-07T18%3A42%3A58Z&ske=2025-05-13T19%3A42%3A58Z&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skoid=8ebb0df1-a278-4e2e-9c20-f2d373479b3a&skv=2019-02-02&sv=2018-11-09&sr=b&sp=r&spr=https%2Chttp&sig=3O0esSlaIYexpAuNmSYS5hnd8o%2FxCcglIapjdQ39nOE%3D&az=oaivgprodscus)
#
# ## 💡 Da dove nasce l'idea
#
# Vendere e comprare vestiti usati può essere complicato, tanto che spesso si rinuncia per frustrazione.
#
# I fondatori di LookBook hanno vissuto questa difficoltà in prima persona e hanno deciso di creare un sistema più semplice e veloce per dare nuova vita ai capi.
#
# ## 🌟 Vision
# > ♻️ **Normalizzare l'utilizzo dell'abbigliamento second-hand, dando una seconda vita a ogni capo dimenticato nell'armadio.**
#
# ## 🧭 Mission
# > Promuovere un modello di consumo sostenibile e diffondere la cultura del riuso come scelta consapevole per il pianeta.
#
# ## 👥 Chi siamo
#
# I fondatori di LookBook sono tre ex professionisti del settore del fast fashion che da un paio d'anni hanno deciso di cambiare rotta.
#
# Il loro obiettivo è rivoluzionare il concetto di second-hand, allontanandolo dai pregiudizi che lo vedono come qualcosa di poco attraente, fuori moda o legato solo al risparmio.
#
# Per LookBook, l'abbigliamento di seconda mano significa:
# - Qualità
# - Funzionalità
# - Sostenibilità
#
# LookBook vuole dare una seconda vita a capi belli, funzionali e a volte in molti casi praticamente nuovi, perché acquistati d'impulso e mai indossati.
#
# ## ⚙️ Come funziona
#
# Dopo aver scaricato l'app, gli utenti possono caricare le foto dei capi che desiderano vendere direttamente sul proprio profilo personale. L'app fornisce una stima del prezzo medio di vendita in base alle caratteristiche del capo.
#
# L'app offre anche l'opzione **Swap**, che permette di scambiare un capo con un altro utente, a condizione che entrambe le parti accettino la proposta.
#
# *Il servizio è attualmente disponibile in tutta Italia.*
#
# Per chi desidera donare i propri vestiti, è disponibile una lista di Onlus partner che raccolgono indumenti da destinare a persone in difficoltà.
#
# ---
#
# ## 🎯 Obiettivo del Progetto
#
# Realizzare un'applicazione Python (su Jupyter Notebook) per gestire un catalogo di vestiti second-hand caricati dagli utenti, con funzioni base e avanzate, simulando il backend di LookBook.
#
# ## 📋 Analisi dei Requisiti
#
# ### Funzionalità base:
# - ✅ Inserimento nuovi capi (nome, marca, taglia, colore, prezzo, condizione, categoria, disponibilità)
# - ✅ Visualizzazione capi presenti in catalogo
# - ✅ Modifica dati di un capo già inserito
# - ✅ Eliminare capi presenti
# - ✅ Ricerca di capi (tramite criterio testuale)
#
#
# ### Funzionalità avanzate:
# - 🔍 **Filtraggio avanzato**
#   - Solo capi "nuovi"
#   - Solo "marca X"
#   - Solo "per scambio"
#   - Per fascia di prezzo
#   - ecc.
#
# - 💰 **Stima prezzo medio dinamica**
#   - In base ad attributi ( condizione + categoria)
#
# - 📊 **Statistiche**:
#   - Numero capi per categoria
#   - Percentuale per condizioni
#   - Percentuali disponibilità
#
# ## 🗂️ Struttura dei Dati
#
# ### Attributi di ogni capo:
# | Attributo | Descrizione |
# |-----------|-------------|
# | `id` | Univoco, generato automaticamente |
# | `nome` | Nome del capo |
# | `marca` | Brand del capo |
# | `taglia` | Taglia del capo |
# | `colore` | Colore principale |
# | `prezzo` | Prezzo |
# | `condizione` | Nuovo, usato, ecc. |
# | `categoria` | T-shirt, pantalone, scarpe, ecc. |
# | `modalità_disponibilità` | Vendita, scambio, donazione |
#
# ### Rappresentazione:
# - **Lista di dizionari**
#
# ## 🛣️ Roadmap di sviluppo
#
# | Fase | Descrizione | Priorità |
# |------|-------------|----------|
# | 1 | Strutturazione dei dati (dizionari) | Alta |
# | 2 | Funzioni base (inserimento, visualizzazione, modifica, ecc) | Alta |
# | 3 | Funzioni avanzate (filtri avanzati) | Media |
# | 4 | Stima prezzo media dinamica | Media |
# | 5 | Statistiche sui capi | Bassa |
#
# ## 📑 Organizzazione Notebook:
#
# - 📄 **Introduzione** (descrizione progetto)
# - 🛠️ **Setup** (inizializzazione dati)
# - ✍️ **Funzioni Base**
# - 🔍 **Funzioni Avanzate**
# - 📊 **Statistiche**
# - 🚀 **Testing finale** (esempi pratici d'uso delle funzioni)
#
# ## 📚 Dettaglio Funzioni da Progettare
#
# | Nome Funzione | Cosa farà |
# |---------------|-----------|
# | `insert_capo()` | Inserisce un nuovo capo nella lista globale |
# | `genera_id()` | Genera un ID incrementale per i capi inseriti |
# | `view_capi()` | Visualizza tutti i capi registrati |
# | `stampa_tabella_capi()` | Visualizza in capi in formato tabella |
# | `modifica_capo()` | Permette di modificare i dati di un capo tramite il suo ID |
# | `elimina_capo()` | Inserisce un nuovo capo nella lista globale |
# | `ricerca_capo()` | Cerca capi tramite criteri testuali |
# | `filtra_capi()` | Filtra capi secondo criteri avanzati (es: solo "nuovi", solo "scambio", fascia di prezzo) |
# | `statistiche_capi()` | Raccoglie statistiche generali: numero capi, per tipologia, per stato d'uso, prezzo medio |
# | `stima_prezzo()` | Stima il prezzo medio di un capo basandosi su attributi categoria e condizione  |
# | `view_carrello()` | Visualizza il carrello e il totale in € |
# | `menu_carrello()` | Gestisce il sotto menù carrello |
# | `aggiungi_al_carrello()` | Aggiunge elemento al carrello |
# | `rimuovi_dal_carrello()` | Rimuove elemento al carrello |
# | `svuota_carrello()` | Rimuove tutti gli elementi dal carrello |
# | `menu_principale()` | Visualizza menù principale |
# | `main()` | Gestisce il menù principale
# | `funzioni_avanzate()` | Gestisce sotto menù avanzate |
#
#
# ## 🔄 Dettaglio Flusso Utente
#
# 1. **Avvio programma** → Messaggio di benvenuto
# 2. **Menu principale** → L'utente sceglie l'azione:
#    - Inserisci un nuovo capo
#    - Visualizzare tutti i capi
#       - Aggiungi al carrello
#    - Modificare un capo
#    - Elimina capi
#    - Cercare un capo
#       - Aggiungi al carrello
#    - Funzioni avanzate (filtri, stima prezzi, statistiche)
#       - Ricerca tramite filtri
#          - Aggiungi al carrello
#       - Statistiche generali
#       - Torna al menù principale
#    - Visualizza carrello
# 3. **Esecuzione** della funzione scelta
# 4. **Tornare** al menu principale o uscire

# %%
# Lista globale per i capi
capi_lista = [
    {
        "id": 1,
        "nome": "Maglietta",
        "marca": "OVS",
        "taglia": "M",
        "colore": "Blu",
        "prezzo": 25.00,
        "condizione": "Usato buone condizioni",
        "categoria": "T-shirt",
        "modalità_disponibilità": "scambio"
    },
    
    {
        "id": 2,
        "nome": "Pantalone estivo",
        "marca": "Levi's",
        "taglia": "XL",
        "colore": "Verde",
        "prezzo": 15.0,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Pantalone",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 3,
        "nome": "Giubotto Sella",
        "marca": "Primark",
        "taglia": "S",
        "colore": "Bianco",
        "prezzo": 0.0,
        "condizione": "Usato buone condizioni",
        "categoria": "Giubbotto",
        "modalità_disponibilità": "donazione"
    },
    {
        "id": 4,
        "nome": "Pullover",
        "marca": "Terranova",
        "taglia": "XL",
        "colore": "Altro Colore",
        "prezzo": 0.0,
        "condizione": "Usato buone condizioni",
        "categoria": "Maglioni",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 5,
        "nome": "Sandali",
        "marca": "Ralph Lauren",
        "taglia": "XS",
        "colore": "Celeste",
        "prezzo": 50.00,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Scarpe",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 6,
        "nome": "Camicia a righe",
        "marca": "Uniqlo",
        "taglia": "L",
        "colore": "Verde",
        "prezzo": 0.0,
        "condizione": "Nuovo",
        "categoria": "Camicia",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 7,
        "nome": "Camicia",
        "marca": "H&M",
        "taglia": "XXXL",
        "colore": "Rosso",
        "prezzo": 0.0,
        "condizione": "Usato buone condizioni",
        "categoria": "Camicia",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 8,
        "nome": "Chino",
        "marca": "Zara",
        "taglia": "XS",
        "colore": "Blu",
        "prezzo": 14.00,
        "condizione": "Usato buone condizioni",
        "categoria": "Acessori",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 9,
        "nome": "Trial F45",
        "marca": "Adidas",
        "taglia": "XL",
        "colore": "Nero",
        "prezzo": 0.0,
        "condizione": "Nuovo",
        "categoria": "Scarpe",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 10,
        "nome": "Gilet",
        "marca": "Prada",
        "taglia": "XXS",
        "colore": "Celeste",
        "prezzo": 110.00,
        "condizione": "Usato ottime condizioni",
        "categoria": "Giubotto",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 11,
        "nome": "Shorts",
        "marca": "Nike",
        "taglia": "XS",
        "colore": "Marrone",
        "prezzo": 0.0,
        "condizione": "Usato buone condizioni",
        "categoria": "Pantaloni",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 12,
        "nome": "Ballerine",
        "marca": "Ralph Lauren",
        "taglia": "L",
        "colore": "Altro Colore",
        "prezzo": 0.0,
        "condizione": "Usato buone condizioni",
        "categoria": "Scarpe",
        "modalità_disponibilità": "donazione"
    },
    {
        "id": 13,
        "nome": "Sandalo",
        "marca": "Prada",
        "taglia": "XXXS",
        "colore": "Nero",
        "prezzo": 0.0,
        "condizione": "Nuovo",
        "categoria": "Scarpe",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 14,
        "nome": "Stivali",
        "marca": "Uniqlo",
        "taglia": "L",
        "colore": "Bianco",
        "prezzo": 0.0,
        "condizione": "Usato ottime condizioni",
        "categoria": "Scarpe",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 15,
        "nome": "Felpa",
        "marca": "Zara",
        "taglia": "XS",
        "colore": "Celeste",
        "prezzo": 0.0,
        "condizione": "Usato buone condizioni",
        "categoria": "Maglioni",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 16,
        "nome": "Felpa",
        "marca": "Puma",
        "taglia": "L",
        "colore": "Celeste",
        "prezzo": 17.00,
        "condizione": "Usato ottime condizioni",
        "categoria": "Maglioni",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 17,
        "nome": "Mocassini",
        "marca": "GAP",
        "taglia": "L",
        "colore": "Giallo",
        "prezzo": 60.0,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Scarpe",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 18,
        "nome": "Chino",
        "marca": "Nike",
        "taglia": "XL",
        "colore": "Blu",
        "prezzo": 0.0,
        "condizione": "Usato buone condizioni",
        "categoria": "Acessori",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 19,
        "nome": "Park",
        "marca": "Gucci",
        "taglia": "S",
        "colore": "Celeste",
        "prezzo": 0.0,
        "condizione": "Usato ottime condizioni",
        "categoria": "Giubotto",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 20,
        "nome": "Tuta",
        "marca": "Nike",
        "taglia": "XXXS",
        "colore": "Altro Colore",
        "prezzo": 0.0,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Maglioni",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 21,
        "nome": "Gonna",
        "marca": "H&M",
        "taglia": "S",
        "colore": "Nero",
        "prezzo": 19.00,
        "condizione": "Usato ottime condizioni",
        "categoria": "Pantaloni",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 22,
        "nome": "Jeans",
        "marca": "Uniqlo",
        "taglia": "XXS",
        "colore": "Viola",
        "prezzo": 41.00,
        "condizione": "Usato buone condizioni",
        "categoria": "Pantaloni",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 23,
        "nome": "Giacca",
        "marca": "Geox",
        "taglia": "S",
        "colore": "Nero",
        "prezzo": 0.0,
        "condizione": "Usato condizioni accettabili",
        "categoria": "giubotto",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 24,
        "nome": "Pullover",
        "marca": "Adidas",
        "taglia": "S",
        "colore": "Verde",
        "prezzo": 0.0,
        "condizione": "Usato buone condizioni",
        "categoria": "maglione",
        "modalità_disponibilità": "donazione"
    },
    {
        "id": 25,
        "nome": "Maglietta",
        "marca": "Gucci",
        "taglia": "XL",
        "colore": "Verde",
        "prezzo": 0.0,
        "condizione": "Nuovo",
        "categoria": "T-shirt",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 26,
        "nome": "Felpa",
        "marca": "H&M",
        "taglia": "S",
        "colore": "Verde",
        "prezzo": 0.0,
        "condizione": "Nuovo",
        "categoria": "Maglioni",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 27,
        "nome": "Salopette",
        "marca": "Gucci",
        "taglia": "XXXL",
        "colore": "Bianco",
        "prezzo": 0.0,
        "condizione": "Usato buone condizioni",
        "categoria": "Acessori",
        "modalità_disponibilità": "donazione"
    },
    {
        "id": 28,
        "nome": "Pantalone",
        "marca": "H&M",
        "taglia": "XXXL",
        "colore": "Giallo",
        "prezzo": 0.0,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Pantalone",
        "modalità_disponibilità": "donazione"
    },
    {
        "id": 29,
        "nome": "Gonna",
        "marca": "H&M",
        "taglia": "XXXL",
        "colore": "Celeste",
        "prezzo": 0.0,
        "condizione": "Usato ottime condizioni",
        "categoria": "Pantaloni",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 30,
        "nome": "Felpa",
        "marca": "Zara",
        "taglia": "XXXS",
        "colore": "Nero",
        "prezzo": 15.00,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Maglioni",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 31,
        "nome": "Sneakers",
        "marca": "Gucci",
        "taglia": "M",
        "colore": "Bianco",
        "prezzo": 43.00,
        "condizione": "Usato ottime condizioni",
        "categoria": "Scarpe",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 32,
        "nome": "Hoodie",
        "marca": "G-Star RAW",
        "taglia": "XXS",
        "colore": "Viola",
        "prezzo": 70.00,
        "condizione": "Nuovo",
        "categoria": "Cappelli",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 33,
        "nome": "Tuta",
        "marca": "H&M",
        "taglia": "XXXS",
        "colore": "Viola",
        "prezzo": 0.0,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Maglioni",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 34,
        "nome": "Cardigan",
        "marca": "Terranova",
        "taglia": "XS",
        "colore": "Viola",
        "prezzo": 5.00,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Maglioni",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 35,
        "nome": "Sciarpa",
        "marca": "Zara",
        "taglia": "L",
        "colore": "Celeste",
        "prezzo": 0.0,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Accessori",
        "modalità_disponibilità": "donazione"
    },
    {
        "id": 36,
        "nome": "Shorts",
        "marca": "Prada",
        "taglia": "L",
        "colore": "Viola",
        "prezzo": 46.00,
        "condizione": "Usato buone condizioni",
        "categoria": "Pantaloni",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 37,
        "nome": "Hoodie",
        "marca": "Nike",
        "taglia": "M",
        "colore": "Giallo",
        "prezzo": 0.0,
        "condizione": "Nuovo",
        "categoria": "Cappelli",
        "modalità_disponibilità": "donazione"
    },
    {
        "id": 38,
        "nome": "Maglietta Vintage",
        "marca": "Levi's",
        "taglia": "L",
        "colore": "Nero",
        "prezzo": 24.00,
        "condizione": "Usato buone condizioni",
        "categoria": "T-shirt",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 39,
        "nome": "Pullover",
        "marca": "Zara",
        "taglia": "XS",
        "colore": "Verde",
        "prezzo": 0.0,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Maglione",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 40,
        "nome": "Sandali 40",
        "marca": "Adidas",
        "taglia": "XXS",
        "colore": "Rosso",
        "prezzo": 0.0,
        "condizione": "Nuovo",
        "categoria": "Scarpe",
        "modalità_disponibilità": "donazione"
    },
    {
        "id": 41,
        "nome": "Maglietta Vintage",
        "marca": "Nike",
        "taglia": "XL",
        "colore": "Rosso",
        "prezzo": 0.0,
        "condizione": "Nuovo",
        "categoria": "T-shirt",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 42,
        "nome": "Maglietta",
        "marca": "Uniqlo",
        "taglia": "XL",
        "colore": "Giallo",
        "prezzo": 0.0,
        "condizione": "Usato buone condizioni",
        "categoria": "T-shirt",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 43,
        "nome": "Pantalone",
        "marca": "Gucci",
        "taglia": "M",
        "colore": "Rosso",
        "prezzo": 0.0,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Pantalone",
        "modalità_disponibilità": "scambio"
    },
    {
        "id": 44,
        "nome": "Espadrillas",
        "marca": "Prada",
        "taglia": "L",
        "colore": "Rosso",
        "prezzo": 63.00,
        "condizione": "Usato ottime condizioni",
        "categoria": "Scarpe",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 45,
        "nome": "Pullover",
        "marca": "Adidas",
        "taglia": "XXS",
        "colore": "Bianco",
        "prezzo": 13.50,
        "condizione": "Usato ottime condizioni",
        "categoria": "Maglione",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 46,
        "nome": "Jeans",
        "marca": "Nike",
        "taglia": "M",
        "colore": "Verde",
        "prezzo": 0.0,
        "condizione": "Usato buone condizioni",
        "categoria": "Pantalone",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 47,
        "nome": "Cardigan",
        "marca": "Tommy Hilfiger",
        "taglia": "L",
        "colore": "Blu",
        "prezzo": 17.00,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Maglione",
        "modalità_disponibilità": "vendita"
    },
    {
        "id": 48,
        "nome": "Felpa 48",
        "marca": "Adidas",
        "taglia": "L",
        "colore": "Bianco",
        "prezzo": 0.0,
        "condizione": "Usato ottime condizioni",
        "categoria": "Maglione",
        "modalità_disponibilità": "donazione"
    },
    {
        "id": 49,
        "nome": "Pantalone",
        "marca": "FILA",
        "taglia": "XXL",
        "colore": "Grigio",
        "prezzo": 0.0,
        "condizione": "Usato buone condizioni",
        "categoria": "Pantalone",
        "modalità_disponibilità": "donazione"
    },
    {
        "id": 50,
        "nome": "Hoodie",
        "marca": "Reebok",
        "taglia": "XXXL",
        "colore": "Marrone",
        "prezzo": 0.0,
        "condizione": "Usato condizioni accettabili",
        "categoria": "Cappelli",
        "modalità_disponibilità": "donazione"
    }
]

# Elenco per selezione tipologia di capo
tipi = {
        "1": "T-shirt",
        "2": "Polo",
        "3": "Camicia",
        "4": "Pantalone",
        "5": "Maglione",
        "6": "Giubotto",
        "7": "Scarpe",
        "8": "Cappelli",
        "9": "Accessori"
    }
# Elenco per selezione taglia
taglie = {
        "1": "XXXL",
        "2": "XXL",
        "3": "XL",
        "4": "L",
        "5": "M",
        "6": "S",
        "7": "XS",
        "8": "XXS",
        "9": "XXXS"
    }
# Elenco per elezione colore
colori = {
        "1": "Rosso",
        "2": "Blu",
        "3": "Bianco",
        "4": "Verde",
        "5": "Viola",
        "6": "Giallo",
        "7": "Celeste",
        "8": "Nero",
        "9": "Grigio",
        "10": "Marrone",
        "11": "Altro Colore",
    }
# Elenco per selezione disponibilità
disponibilita = {
        "1": "Vendita",
        "2": "Scambio",
        "3": "Donazione",
    }

# Elenco per selezione condizione

condizione = {
        "1" : "Nuovo",
        "2" : "Usato ottime condizioni",
        "3" : "Usato buone condizioni",
        "4" : "Usato condizioni accettabili",
    }

# Prezzo base categoria per stima
prezzo_base_categoria = {
    "T-shirt": 15,
    "Polo": 20,
    "Camicia": 25,
    "Pantalone": 30,
    "Maglione": 35,
    "Giubotto": 50,
    "Scarpe": 60,
    "Cappelli": 15,
    "Accessori": 10
}
# Moltiplicatori per funzione stima
moltiplicatore_condizione = {
    "Nuovo": 1.0,
    "Usato ottime condizioni": 0.8,
    "Usato buone condizioni": 0.6,
    "Usato condizioni accettabili": 0.4
}
# Inizializza il conteggio delle categorie
conteggio_categorie = {
        "T-shirt": 0, "Polo": 0, "Camicia": 0, "Pantalone": 0,
        "Maglione": 0, "Giubotto": 0, "Scarpe": 0, "Cappelli": 0, "Accessori": 0
}
# Inizializza il conteggio delle condizioni
conteggio_condizione = {
        "Nuovo": 0, "Usato ottime condizioni": 0, "Usato buone condizioni": 0,
        "Usato condizioni accettabili": 0             
}
# Inizializza il conteggio delle disponibilità
conteggio_disponibilità = {
        "vendita": 0, "scambio": 0, "donazione": 0,
}    
# Elenco carrello
carrello = []

# %%
# --- SETUP INIZIALE ---

def genera_id():
    """Genera un ID univoco incrementale per un nuovo capo.
    
    Returns:
        int: Il prossimo ID disponibile, basato sul massimo ID esistente + 1.
    """
    return max([capo["id"] for capo in capi_lista], default=0) + 1



# --- FUNZIONI BASE ---

def insert_capo():
    """Inserisce un nuovo capo nell'inventario tramite input utente.
    
    Guida l'utente attraverso l'inserimento di tutte le informazioni necessarie
    per un nuovo capo d'abbigliamento: nome, tipologia, taglia, colore, marca,
    condizione, disponibilità e prezzo (se in vendita).
    
    Returns:
        None
    """
    print("\n--- Inserisci un nuovo capo ---")
    nome = input("Inserisci il nome del nuovo prodotto: ").strip()

    # Selezione della tipologia del capo
    print("\nScegli la tipologia :")
    for key, value in tipi.items():
        print(f"{key}. {value}")

    # Ciclo per assicurarsi che l'utente selezioni una tipologia valida
    while True:
        tipo_input = input("Scegli fra queste tipologie (1-9): ")
        if tipo_input in tipi:
            tipo = tipi[tipo_input]
            break
        else:
            print("Opzione non valida. Riprova.")

    # Selezione della taglia
    print("\nScegli la taglia:")
    for key, value in taglie.items():
        print(f"{key}. {value}")

    # Ciclo per assicurarsi che l'utente selezioni una taglia valida
    while True:
        taglia_input = input("Seleziona la taglia (1-9): ")
        if taglia_input in taglie:
            taglia = taglie[taglia_input]
            break
        else:
            print("Opzione non valida. Riprova.")

    # Selezione del colore
    print("\nScegli il colore:")
    for key, value in colori.items():
        print(f"{key}. {value}")

    # Ciclo per assicurarsi che l'utente selezioni un colore valido
    while True:
        colore_input = input("Seleziona il colore (1-11): ")
        if colore_input in colori:
            colore = colori[colore_input]
            break
        else:
            print("Opzione non valida. Riprova.")

    # Inserimento della marca
    marca = input("Inserisci la marca del nuovo prodotto: ").strip()

    # Selezione delle condizioni del capo
    print("\nScegli la condizione:")
    for key, value in condizione.items():
        print(f"{key}. {value}")

    # Ciclo per assicurarsi che l'utente selezioni una condizione valida
    while True:
        condizione_input = input("Seleziona la condizione (1-4): " )
        if condizione_input in condizione:
            condizioni = condizione[condizione_input]
            break
        else:
            print("Opzione non valida. Riprova.")


   # Selezione della disponibilità con integrata funzione di stima prezzo
    print("\nModalità di disponibilità:")
    for key, value in disponibilita.items():
        print(f"{key}. {value}")

    # Ciclo per assicurarsi che l'utente selezioni una disponibilità valida
    # e gestisca correttamente l'inserimento del prezzo se necessario
    while True:
        disp_input = input("Seleziona la disponibilità (1-3): ")
        if disp_input in disponibilita:
            disposizione = disponibilita[disp_input]
            
            # Se la disponibilità è "vendita", si gestisce il prezzo
            if disp_input == "1":  # Vendita
                while True:
                    # Proposta del sistema di stima automatica del prezzo
                    scelta_stima = input("Vuoi che il sistema ti consigli un prezzo? (s/n): ").strip().lower()
                    if scelta_stima == "s":
                         # Calcolo del prezzo stimato basato su categoria e condizioni
                        prezzo_stimato = stima_prezzo(tipo, condizioni)
                        print(f"💡 Il sistema suggerisce un prezzo di: €{prezzo_stimato:.2f}")
                        # Conferma dell'utilizzo del prezzo stimato
                        while True:
                            conferma = input("Vuoi usare questo prezzo ? (s/n): ").strip().lower()
                            if conferma == "s":
                                prezzo = prezzo_stimato
                                break  # esci da scelta_stima
                            elif conferma == "n":
                                 # Inserimento manuale del prezzo con validazione
                                while True:                    
                                    try:
                                        prezzo = float(input("Inserisci il prezzo: "))
                                        if prezzo < 0:
                                            raise ValueError
                                        break
                                    except ValueError:
                                        print("⚠️ Prezzo non valido. Riprova.")
                                break                        
                            else:
                                print("⚠️ Inserisci solo 's' per sì o 'n' per no.")
                        break  # esci da scelta_stima
                    elif scelta_stima == "n":
                        while True:
                            try:
                                prezzo = float(input("Inserisci il prezzo: "))
                                if prezzo < 0:
                                    raise ValueError
                                break
                            except ValueError:
                                print("⚠️ Prezzo non valido. Riprova.")
                        break
                    else:
                        print("⚠️ Inserisci solo 's' per sì o 'n' per no.")
            else:
                # Se non è in vendita, il prezzo è impostato a 0
                prezzo = 0.0
            break
        else:
            print("⚠️ Opzione non valida. Riprova.")    

     # Creazione e salvataggio del capo nella lista
    capo = {
        "id": genera_id(),
        "nome": nome,
        "categoria": tipo,
        "taglia": taglia,
        "colore": colore,
        "marca": marca,
        "modalità_disponibilità": disposizione,
        "prezzo": prezzo,
        "condizione": condizioni,
        
    }

    # Aggiunta del capo alla lista e conferma
    capi_lista.append(capo)
    print(f"\n✅ {nome} è stato aggiunto con successo a capi_lista!\n")
    print("\n🧾 Riepilogo capo aggiunto:")
    for k, v in capo.items():
        print(f" - {k}: {v}")
    


def stampa_tabella_capi(lista, messaggio=None, nessun_risultato="Nessun capo trovato."):
    """Stampa una tabella formattata dei capi d'abbigliamento.
    
    Args:
        lista (list): Lista di dizionari contenente i capi da visualizzare.
        messaggio (str, optional): Messaggio da mostrare prima della tabella.
        nessun_risultato (str, optional): Messaggio da mostrare se la lista è vuota.
            Default: "Nessun capo trovato."
    
    Returns:
        None
    """
        if lista:
            if messaggio:
                print(messaggio)
                 # Intestazione della tabella
            print(f"{'ID':<3} {'Nome':<20} {'Marca':<15} {'Taglia':<6} {'Colore':<15} {'Prezzo (€)':<11} {'Condizione':<30} {'Disponibilità'}")
            print("-" * 120)
            # Righe della tabella
            for capo in lista:
                print(f"{capo['id']:<3} {capo['nome']:<20} {capo['marca']:<15} {capo['taglia']:<6} {capo['colore']:<15} "
                      f"{capo['prezzo']:<11.2f} {capo['condizione']:<30} {capo['modalità_disponibilità'].capitalize()}")
        else:
            print(nessun_risultato)   



def view_capi():
     """Visualizza tutti i capi disponibili nell'inventario.
    
    Mostra tutti i capi in formato tabella e offre la possibilità di 
    aggiungere articoli al carrello.
    
    Returns:
        None
    """
    if not capi_lista:
        print("❌ Nessun capo disponibile al momento.")
        return
        
    # Visualizza i capi in formato tabella
    stampa_tabella_capi(capi_lista, messaggio="📦 Prodotti disponibili:\n")
    # Offre la possibilità di aggiungere capi al carrello
    aggiungi_al_carrello(capi_lista)



# Permette la modifica di un capo esistente nell'inventario.
# L'utente può modificare tutti i dettagli del capo selezionato tramite ID,
# con la possibilità di mantenere i valori esistenti premendo invio.
def modifica_capo():
    """Modifica un capo esistente nell'inventario.
    
    Permette all'utente di modificare tutti i dettagli del capo selezionato
    tramite ID, con la possibilità di mantenere i valori esistenti premendo invio.
    
    Returns:
        None
    """
    print("\n--- Modifica un capo ---")
    try:
        src_id = int(input("🔍 Inserisci l'ID del prodotto da modificare: "))
    except ValueError:
        print("⚠️ L'ID deve essere un numero.")
        return

    # Cerca il capo con l'ID specificato
    for capo in capi_lista:
        if capo["id"] == src_id:
            print(f"Trovato capo: {capo['nome']} (ID: {src_id})")

            # Modifica proprietà: per ognuna si può mantenere il valore attuale o inserirne uno nuovo
            nuovo_nome = input(f"Inserisci il nuovo nome [{capo['nome']}]: (Premi Invio per mantenere il valore corrente) ") or capo["nome"]
            nuova_marca = input(f"Inserisci la nuova marca [{capo['marca']}]: (Premi Invio per mantenere il valore corrente) ") or capo["marca"]

            # Modifica categoria
            print("Scegli la nuova categoria:")
            for k, v in tipi.items():
                print(f"{k}. {v}")
            nuova_categoria = tipi.get(input(f"Scelta [{capo['categoria']}]: (Premi Invio per mantenere il valore corrente) "), capo["categoria"])

            # Modifica taglia
            print("Scegli la nuova taglia:")
            for k, v in taglie.items():
                print(f"{k}. {v}")
            nuova_taglia = taglie.get(input(f"Scelta [{capo['taglia']}]: (Premi Invio per mantenere il valore corrente) "), capo["taglia"])

            # Modifica colore
            print("Scegli il nuovo colore:")
            for k, v in colori.items():
                print(f"{k}. {v}")
            nuovo_colore = colori.get(input(f"Scelta [{capo['colore']}]: (Premi Invio per mantenere il valore corrente) "), capo["colore"])

            # Modifica prezzo con gestione errori
            try:
                nuovo_prezzo = input(f"Inserisci il nuovo prezzo [{capo['prezzo']} €]: ")
                nuovo_prezzo = float(nuovo_prezzo) if nuovo_prezzo else capo["prezzo"]
            except ValueError:
                print("⚠️ Prezzo non valido. Mantenuto il valore precedente.")
                nuovo_prezzo = capo["prezzo"]

            # Modifica condizione
            print("Scegli la nuova condizione:")
            for k, v in condizione.items():
                print(f"{k}. {v}")
            nuova_condizione = condizione.get(input(f"Scelta [{capo['condizione']}]: (Premi Invio per mantenere il valore corrente) "), capo["condizione"])
            
            print("Scegli la nuova modalità di disponibilità:")
            for k, v in disponibilita.items():
                print(f"{k}. {v}")
            nuova_disponibilita = disponibilita.get(input(f"Scelta [{capo['modalità_disponibilità']}]: (Premi Invio per mantenere il valore corrente) "), capo["modalità_disponibilità"])

            # Conferma delle modifiche
            conferma = input(f"\nConfermi le modifiche per il capo ID {src_id}? (s/n): ").strip().lower()
            if conferma == 's':
                # Aggiorna tutti i valori del capo con quelli nuovi
                capo.update({
                    "nome": nuovo_nome,
                    "marca": nuova_marca,
                    "categoria": nuova_categoria,
                    "taglia": nuova_taglia,
                    "colore": nuovo_colore,
                    "prezzo": nuovo_prezzo,
                    "condizione": nuova_condizione,
                    "modalità_disponibilità": nuova_disponibilita
                })

                print("✅ Capo aggiornato con successo.")
            else:
                print("❌ Modifica annullata.")
            return
     #l'ID non è stato trovato
    print(f"❌ Nessun capo trovato con ID {src_id}.")


def elimina_capo():
    """Elimina uno o più capi dall'inventario.
    
    Permette l'eliminazione di uno o più capi esistenti nella lista,
    selezionandoli tramite ID. Richiede conferma prima di ogni eliminazione.
    
    Returns:
        None
    """
    print("\n--- Elimina capo/i ---")
    
    # Richiede all'utente uno o più ID separati da virgola
    input_ids = input("Inserisci uno o più ID da eliminare (separati da virgola): ").strip()
    
    # Se l'utente preme solo invio, interrompe la funzione
    if not input_ids:
        print("⚠️ Nessun ID inserito.")
        return

    try:
        # Converte gli ID inseriti in una lista di interi, rimuovendo spazi bianchi
        id_list = [int(i.strip()) for i in input_ids.split(',')]
    except ValueError:
        # Se uno degli ID non è numerico, segnala errore e termina
        print("⚠️ Tutti gli ID devono essere numerici.")
        return

    eliminati = 0 
    
    for src_id in id_list:
        # Cerca il capo nella lista tramite ID 
        capo = next((c for c in capi_lista if c["id"] == src_id), None)
        
        if capo:
            # Chiede conferma prima di eliminare
            conferma = input(f"Eliminare '{capo['nome']}' (ID {src_id})? (s/n): ").strip().lower()
            if conferma == "s":
                capi_lista.remove(capo)  # Rimuove il capo dalla lista
                eliminati += 1
                print(f"✅ Capo ID {src_id} eliminato.")
            else:
                print(f"❎ Capo ID {src_id} non eliminato.")
        else:
            # ID non trovato nella lista
            print(f"❌ Nessun capo trovato con ID {src_id}.")

    # Riepilogo finale
    if eliminati:
        print(f"\n✅ Totale capi eliminati: {eliminati}")
    else:
        print("\nℹ️ Nessun capo eliminato.")



def ricerca_capo():
    """Ricerca capi nell'inventario in base a criteri testuali.
    
    Permette la ricerca di capi in base a diversi campi (nome, marca, categoria,
    taglia, colore, condizione) e mostra i risultati corrispondenti. Offre anche
    la possibilità di aggiungere articoli trovati al carrello.
    
    Returns:
        None
    """
    print("\n--- Ricerca Capi ---")
    print("Puoi cercare per nome, marca, categoria, taglia, colore o condizione.")
    criterio = input("Inserisci un criterio di ricerca: ").strip().lower()

    # Lista per i risultati della ricerca
    risultati = []

    # Cerca il criterio in vari campi di ogni capo (ricerca case-insensitive)
    for capo in capi_lista:
        if(criterio in capo["nome"].lower() or
           criterio in capo["marca"].lower() or
           criterio in capo["categoria"].lower() or
           criterio in capo["taglia"].lower() or
           criterio in capo["colore"].lower() or
           criterio in capo["condizione"].lower()):
           risultati.append(capo)

    # Visualizza i risultati
    stampa_tabella_capi(
        risultati, 
        messaggio=f"\nTrovati {len(risultati)} capi corrispondenti:\n", 
        nessun_risultato="Nessun capo trovato con il criterio inserito."
    )

    # Se ci sono risultati, offre l'opzione di aggiungere al carrello
    if risultati:
        aggiungi_al_carrello(risultati)


# --- FUNZIONI AVANZATE ---

def filtra_capi():
    """Filtra i capi usando criteri multipli avanzati.
    
    Permette all'utente di applicare diversi filtri contemporaneamente
    (categoria, taglia, colore, condizione, disponibilità, prezzo) per trovare
    capi che soddisfano criteri specifici.
    
    Returns:
        None
    """
    print("\n--- Filtra Capi Avanzato ---")
    print("Puoi filtrare i capi per più criteri. Lascia vuoto un filtro se non vuoi applicarlo.\n")

    # Filtro per categoria
    print("Categoria:")
    for k, v in tipi.items():
        print(f"{k}: {v}")
    scelta_categoria = input("Seleziona una categoria (invio per saltare): ").strip()
    categoria = tipi.get(scelta_categoria, "") if scelta_categoria else ""

    # Filtro per taglia
    print("\nTaglia:")
    for k, v in taglie.items():
        print(f"{k}: {v}")
    scelta_taglia = input("Seleziona una taglia (invio per saltare): ").strip()
    taglia = taglie.get(scelta_taglia, "") if scelta_taglia else ""

    # Filtro per colore
    print("\nColore:")
    for k, v in colori.items():
        print(f"{k}: {v}")
    scelta_colore = input("Seleziona un colore (invio per saltare): ").strip()
    colore = colori.get(scelta_colore, "") if scelta_colore else ""

    # Filtro per condizione
    print("\nCondizione:")
    for k, v in condizione.items():
        print(f"{k}: {v}")
    scelta_condizione = input("Seleziona una condizione (invio per saltare): ").strip()
    condizione_sel = condizione.get(scelta_condizione, "") if scelta_condizione else ""

    # Filtro per disponibilità
    print("\nModalità di disponibilità:")
    for k, v in disponibilita.items():
        print(f"{k}: {v}")
    scelta_disponibilita = input("Seleziona la modalità (invio per saltare): ").strip()
    disponibilita_sel = disponibilita.get(scelta_disponibilita, "") if scelta_disponibilita else ""

    # Filtro per prezzo
    prezzo_min = input("\nPrezzo minimo (€) (invio per saltare): ").strip()
    prezzo_max = input("Prezzo massimo (€) (invio per saltare): ").strip()

    # Applicazione dei filtri
    risultati = []
    for capo in capi_lista:
        # Verifica tutti i filtri testuali
        if (
            (not categoria or capo["categoria"] == categoria) and
            (not taglia or capo["taglia"] == taglia) and
            (not colore or capo["colore"] == colore) and
            (not condizione_sel or capo["condizione"].lower() == condizione_sel.lower()) and
            (not disponibilita_sel or capo["modalità_disponibilità"].lower() == disponibilita_sel.lower())
        ):
            # Verifica i filtri numerici (prezzo
            prezzo = capo["prezzo"]
            if (
                (not prezzo_min or prezzo >= float(prezzo_min)) and
                (not prezzo_max or prezzo <= float(prezzo_max))
            ):
                risultati.append(capo)

    # Visualizza i risultati e offre l'opzione di aggiungere al carrello
    stampa_tabella_capi(
        risultati, 
        messaggio=f"\nTrovati {len(risultati)} capi corrispondenti:\n", 
        nessun_risultato="Nessun capo trovato con i filtri inseriti.")
    if risultati:
        aggiungi_al_carrello(risultati)



def stima_prezzo(categoria, condizione):
    """Calcola un prezzo stimato per un capo.
    
    Args:
        categoria (str): La categoria del capo.
        condizione (str): La condizione del capo.
    
    Returns:
        float: Il prezzo stimato basato su categoria e condizione.
    """
    # Ottiene il prezzo base dalla categoria o usa 20 come valore predefinito
    base = prezzo_base_categoria.get(categoria, 20)
    # Ottiene il moltiplicatore dalla condizione o usa 0.5 come valore predefinito
    moltiplicatore = moltiplicatore_condizione.get(condizione, 0.5)

    # Calcola il prezzo stimato
    return base * moltiplicatore



def statistiche_capi():
     """Genera statistiche e grafici sull'inventario attuale.
    
    Utilizza matplotlib per creare grafici che mostrano la distribuzione
    dei capi per categoria, condizione e disponibilità.
    
    Returns:
        None
    """
     
    # Conta le categorie nei capi
    for capo in capi_lista:
        categoria = capo["categoria"]
        condizione = capo["condizione"]
        disponibilità = capo["modalità_disponibilità"]
        # Incrementa i contatori appropriati
        if categoria in conteggio_categorie:
            conteggio_categorie[categoria] += 1
        if condizione in conteggio_condizione:
            conteggio_condizione[condizione] += 1
        if disponibilità in conteggio_disponibilità:
            conteggio_disponibilità[disponibilità] += 1
            
    # Estrai le chiavi e i valori per il grafico delle categorie
    x = list(conteggio_categorie.keys())
    y = list(conteggio_categorie.values())

    # Imposta la figura complessiva
    plt.figure(figsize=(15,5))

    # PRIMO GRAFICO: Distribuzione per categoria (grafico a barre)
    plt.subplot(1, 3, 1)    
    plt.bar(x, y, color='orange')

    # Aggiungi i numeri sopra le barre
    for i in range(len(x)):
        plt.text(x[i], y[i] + 0.1, str(y[i]), ha='center', va='bottom')  # Aggiungi i numeri sopra le barre

    # Imposta l'orientamento delle etichette sull'asse x
    plt.xticks(rotation=45)

    # Aggiungi titolo e etichette
    plt.title("Quantità per categorie")
    plt.xlabel("Categoria")
    plt.ylabel("Quantità")
    
    # SECONDO GRAFICO: Distribuzione per condizione (grafico a torta)
    plt.subplot(1, 3, 2)

    x_pie1 = list(conteggio_condizione.keys())
    y_pie1 = list(conteggio_condizione.values())

    plt.pie(y_pie1, labels=x_pie1, autopct='%1.1f%%')
    plt.title("Percentuale capi per condizione")

   # TERZO GRAFICO: Distribuzione per disponibilità (grafico a torta)
    plt.subplot(1, 3, 3)

    x_pie2 = list(conteggio_disponibilità.keys())
    y_pie2 = list(conteggio_disponibilità.values())

    plt.pie(y_pie2, labels=x_pie2, autopct='%1.1f%%')
    plt.title("Percentuale capi per disponibilità")

    # Rende il layout più compatto
    plt.tight_layout()
    # Mostra i grafici
    plt.show()



def view_carrello():
    """Visualizza il contenuto attuale del carrello e il totale.
    
    Mostra tutti i capi presenti nel carrello in formato tabella
    e calcola il totale del prezzo.
    
    Returns:
        None
    """
    print("\n🛒 Riepilogo carrello:")
    if not carrello:
        print("Il carrello è vuoto.")
        return

    # Visualizza i capi nel carrello
    stampa_tabella_capi(carrello, messaggio="", nessun_risultato="")
    # Calcola e mostra il totale
    totale = sum(capo["prezzo"] for capo in carrello)
    print(f"\nTotale: {totale:.2f} €")



def menu_carrello():
    """Gestisce il menu del carrello con varie opzioni.
    
    Presenta un menu interattivo per la gestione del carrello con opzioni
    per visualizzare, rimuovere articoli, svuotare il carrello o tornare
    al menu principale.
    
    Returns:
        None
    """
    while True:
        print("\n--- Gestione Carrello ---")
        print("1. Visualizza contenuto carrello")
        print("2. Rimuovi un capo dal carrello")
        print("3. Svuota carrello")
        print("4. Torna al menu principale")

        scelta = input("Scegli un'opzione: ").strip()

        if scelta == "1":
            view_carrello()
        elif scelta == "2":
            rimuovi_dal_carrello()
        elif scelta == "3":
            svuota_carrello()
        elif scelta == "4":
            break
        else:
            print("❌ Scelta non valida.")



def aggiungi_al_carrello(lista_capi):
    """Permette di aggiungere capi al carrello.
    
    Chiede all'utente gli ID dei capi da aggiungere e verifica che
    l'ID esista nella lista e che non sia già nel carrello.
    
    Args:
        lista_capi (list): Lista dei capi da cui selezionare per l'aggiunta.
    
    Returns:
        None
    """
    
    while True:
        scelta = input("Vuoi aggiungere uno o più capi al carrello? (s/n): ").strip().lower()
        if scelta == "n":
            return
        elif scelta == "s":
            # Chiede gli ID dei capi da aggiungere
            ids = input("Inserisci gli ID dei capi separati da virgola (es. 1,3,5): ").split(",")
            aggiunti = 0
            for id_input in ids:
                id_input = id_input.strip()
                if not id_input.isdigit():
                    print(f"⚠️  ID non valido: '{id_input}'")
                    continue
                    
                id_capo = int(id_input)
                # Cerca il capo nella lista
                capo = next((c for c in lista_capi if c["id"] == id_capo), None)
                
                if not capo:
                    print(f"❌ Nessun capo trovato con ID {id_capo}")
                elif any(c["id"] == id_capo for c in carrello):
                    print(f"⚠️  Capo con ID {id_capo} è già nel carrello.")
                else:
                    # Aggiunge il capo al carrello
                    carrello.append(capo)
                    print(f"✅ Capo con ID {id_capo} aggiunto al carrello.")
                    aggiunti += 1
                    
            if aggiunti > 0:
                print(f"\n🔄 Totale articoli nel carrello: {len(carrello)}")
            return
        else:
            print("Inserisci 's' per sì o 'n' per no.")



def rimuovi_dal_carrello():
    """Permette all'utente di rimuovere capi dal carrello.
    
    Mostra il contenuto attuale del carrello e permette all'utente
    di selezionare un capo da rimuovere tramite ID. Continua fino
    a quando l'utente preme INVIO per uscire.

    Returns:
        None
    """
    
    if not carrello:
        print("🛒 Il carrello è vuoto, nulla da rimuovere.")
        return
         
    # Mostra il contenuto attuale del carrello
    view_carrello()
    while True:
        scelta = input("Inserisci l'ID del capo da rimuovere (INVIO per uscire): ").strip()
        if scelta == "":
            break
            
        if not scelta.isdigit():
            print("⚠️ Inserisci un ID numerico valido.")
            continue
            
        id_da_rimuovere = int(scelta)
        # Cerca il capo nel carrello
        capo_da_rimuovere = next((c for c in carrello if c['id'] == id_da_rimuovere), None)
        
        if capo_da_rimuovere:
            # Rimuove il capo dal carrello
            carrello.remove(capo_da_rimuovere)
            print(f"❌ Capo '{capo_da_rimuovere['nome']}' rimosso dal carrello.")
        else:
            print("⚠️ ID non trovato nel carrello.")



def svuota_carrello():
    """Svuota completamente il carrello dopo conferma dell'utente.
    
    Chiede conferma all'utente prima di procedere con lo svuotamento.
    Se il carrello è già vuoto, informa l'utente.

    Returns:
        None
    """
    
    global carrello
    if not carrello:
        print("🛒 Il carrello è già vuoto.")
        return

    # Chiede conferma prima di svuotare
    conferma = input("Sei sicuro di voler svuotare il carrello? (s/n): ").strip().lower()
    if conferma == "s":
        carrello.clear()
        print("✅ Carrello svuotato con successo.")
    else:
        print("Operazione annullata.")

    
     
# --- FUNZIONE MENU PRINCIPALE ---


def menu_principale():
    """Visualizza il menu principale dell'applicazione.
    
    Stampa tutte le opzioni disponibili del menu principale
    numerandole da 1 a 8.

    Returns:
        None
    """
    print("\n--- Menu Principale ---")
    print("1. Inserisci un nuovo capo")
    print("2. Visualizza tutti i capi")
    print("3. Modifica un capo")
    print("4. Elimina capi")
    print("5. Cerca un capo")
    print("6. Funzioni avanzate")
    print("7. Visualizza carrello")
    print("8. Esci")

.
def main():
    """Funzione principale che gestisce il ciclo del programma.
    
    Presenta il menu principale e gestisce la selezione delle opzioni
    finché l'utente non sceglie di uscire (opzione 8).

    Returns:
        None
    """
    while True:
        menu_principale() 
        print("")
        scelta = input("Scegli un'opzione (1-7): ")
        print("")
        
        if scelta == "1":
            insert_capo()
        elif scelta == "2":
            view_capi()
        elif scelta == "3":
            modifica_capo()
        elif scelta == "4":
            elimina_capo()
        elif scelta == "5":
            ricerca_capo()
        elif scelta == "6":
            funzioni_avanzate()  
        elif scelta == "7":
            menu_carrello()      
        elif scelta == "8":
            print("Arrivederci!")
            break
        else:
            print("Opzione non valida. Riprova.")

# --- FUNZIONE SOTTO MENU AVANZATE ---


import matplotlib.pyplot as plt
def funzioni_avanzate():
    """Sottomenu per le funzionalità avanzate del programma.
    
    Offre opzioni per filtrare i capi e visualizzare statistiche.
    Continua fino a quando l'utente sceglie di tornare al menu principale.

    Returns:
        None
    """
    while True:
        print("\n--- Funzioni Avanzate ---\n")
        print("1. Ricerca tramite filtri")
        print("2. Statistiche generali")
        print("3. Torna al menù principale")
        
        scelta_avanzate = input("\nScegli un'opzione (1-3): ")
        
        if scelta_avanzate == "1":
            filtra_capi()
        elif scelta_avanzate == "2":
            statistiche_capi()
        elif scelta_avanzate == "3":
            break  # Esce dal sottomenu e ritorna al main
        else:
            print("Opzione non valida. Riprova.")

# %%
#### --- AVVIO PROGRAMMA ---

# Verifica che il file sia eseguito direttamente e non importato come modulo
if __name__ == "__main__":
    print("Benvenuto su LookBook Manager! 👚👖♻️")
    main()

# %% [markdown]
# # 📋  Testing finale
#
# | Funzione | Descrizione | Testata | Funzionante |
# |----------|-------------|:-------:|:-----------:|
# | `menu_principale()` | Visualizza menù principale | ✅ | ✅ |
# | `main()` | Gestisce il menù principale | ✅ | ✅ |
# | `funzioni_avanzate()` | Gestisce sotto menù avanzate | ✅ | ✅ |
# | `insert_capo()` | Inserisce un nuovo capo nella lista globale | ✅ | ✅ |
# | `genera_id()` | Genera un ID incrementale per i capi inseriti | ✅ | ✅ |
# | `view_capi()` | Visualizza tutti i capi registrati | ✅ | ✅ |
# | `stampa_tabella_capi()` | Visualizza i capi in formato tabella | ✅ | ✅ |
# | `modifica_capo()` | Permette di modificare i dati di un capo tramite il suo ID | ✅ | ✅ |
# | `elimina_capo()` | Elimina un capo dalla lista globale | ✅ | ✅ |
# | `ricerca_capo()` | Cerca capi tramite criteri testuali | ✅ | ✅ |
# | `filtra_capi()` | Filtra capi secondo criteri avanzati (es: solo "nuovi", solo "scambio", fascia di prezzo) | ✅ | ✅ |
# | `statistiche_capi()` | Raccoglie statistiche generali: numero capi, per tipologia, per stato d'uso, prezzo medio | ✅ | ✅ |
# | `stima_prezzo()` | Stima il prezzo medio di un capo basandosi su attributi categoria e condizione | ✅ | ✅ |
# | `menu_carrello()` | Gestisce il sotto menù carrello | ✅ | ✅ |
# | `view_carrello()` | Visualizza il carrello e il totale in € | ✅ | ✅ |
# | `aggiungi_al_carrello()` | Aggiunge elemento al carrello | ✅ | ✅ |
# | `rimuovi_dal_carrello()` | Rimuove elemento dal carrello | ✅ | ✅ |
# | `svuota_carrello()` | Rimuove tutti gli elementi dal carrello | ✅ | ✅ |
#
# ### Legenda:
# - ✅ = Completato
# - ⬜ = Da completare
# - ❌ = Problemi rilevati
#
# ---
#
# ### Note sui test:
# - Ultima sessione di test: `[08/05/2025]`
# - Test eseguiti da: `[Franco De Giorgio]`
# - Ambiente di test: `[NoteBook Jupyter]`
#
# ### Problemi noti:
# 1. `[Risolti tutti i problemi nell'ultima fase di test]`
#
#
# ### Prossimi test pianificati:
# - `[Nuove funzioni]`: `[Prossimamente]`
